# %%
import pandas as pd

data = pd.read_csv("METABRIC_RNA_Mutation.csv")
# Out:
# /var/folders/wx/8z_5mzk97j78yb7dgp1_fz8h0000gn/T/ipykernel_29176/725479258.py:3: DtypeWarning: Columns (678,688,690,692) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("METABRIC_RNA_Mutation.csv")

# %%
data.describe()
# Out:
#         patient_id  age_at_diagnosis  chemotherapy       cohort  \
# count  1904.000000       1904.000000   1904.000000  1904.000000
# mean   3921.982143         61.087054      0.207983     2.643908
# std    2358.478332         12.978711      0.405971     1.228615
# min       0.000000         21.930000      0.000000     1.000000
# 25%     896.500000         51.375000      0.000000     1.000000
# 50%    4730.500000         61.770000      0.000000     3.000000
# 75%    5536.250000         70.592500      0.000000     3.000000
# max    7299.000000         96.290000      1.000000     5.000000
#
#        neoplasm_histologic_grade  hormone_therapy  \
# count                1832.000000      1904.000000
# mean                    2.415939         0.616597
# std                     0.650612         0.486343
# min                     1.000000         0.000000
# 25%                     2.000000         0.000000
# 50%                     3.000000         1.000000
# ...

# %%
data.corr()['overall_survival_months'].nlargest(10)
# data.corr()['overall_survival_months'].nsmallest(10)
# Out:
# /var/folders/wx/8z_5mzk97j78yb7dgp1_fz8h0000gn/T/ipykernel_29176/2012739418.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()['overall_survival_months'].nlargest(10)
# overall_survival_months    1.000000
# overall_survival           0.384467
# bcl2                       0.165202
# tsc1                       0.163396
# hsd3b7                     0.163043
# stat5b                     0.162798
# igf1r                      0.144011
# map3k1                     0.142373
# mapt                       0.142296
# runx1                      0.138596
# Name: overall_survival_months, dtype: float64

# %%
import os
from PIL import Image

for root, dirs, files in os.walk("./data/IDC_regular_ps50_idx5"):
    for name in files:
        print(os.path.join(root, name))

# %%
from PIL import Image

Image.open('./data/9036/0/9036_idx5_x1051_y2401_class0.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=50x50>
